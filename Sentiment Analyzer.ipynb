# %% [markdown]
# # SWAHILI SENTIMENT ANALYZER

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import re
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# !pip install nltk
# !pip install scikit-learn
# Out:
# Requirement already satisfied: nltk in c:\users\hp\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click->nltk) (0.4.5)
# Requirement already satisfied: scikit-learn in c:\users\hp\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)

# %%
import nltk

nltk.download('swahili-sentiment')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Error loading swahili-sentiment: Package 'swahili-
# [nltk_data]     sentiment' not found in index
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df = pd.read_csv("swahili.csv")

# %% [markdown]
# # Labelled Loaded Data

# %%
df.head(20)
# Out:
#     Unnamed: 0                                               text    labels
# 0            0                 team 2019merimera alikuwa takataka  negative
# 1            1                                     sijafurahishwa  negative
# 2            2                                      kubuni dosari  negative
# 3            3                  bila kusema nilipoteza pesa zangu  negative
# 4            4                       sema kupoteza pesa na wakati  negative
# 5            5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6            6                                  akili yako imeoza  negative
# 7            7                            aki si maisha ni magumu  negative
# 8            8                           enyewe safaricom ni wezi  negative
# 9            9  mtandao duni hata line yao niliweka nyuma ya s...  negative
# 10          10  mtandao wenu wa 4g ni mbaya sana siku hizi taf...  negative
# 11          11  safaricom si muache kucheza na mkopo wa nambar...  negative
# 12          12                                         hauna haki  negative
# 13          13  nyinyi mimi nilinunua laini yenu miaka 20 iliy...  negative
# 14          14  siwezi kuona jinsi sinema hii inavyoweza kuwa ...  negative
# 15          15  ni mbaya sana ni kweli inafaa kuona kwa sababu...  negative
# 16          16  muziki mdogo sana au kitu chochote cha kuzungu...  negative
# 17          17  bado mtaishi kuwa wakora ata hii ofa labda kun...  negative
# 18          18                            nimepoteza masaa mawili  negative
# 19          19                          inaweza kutabirika kidogo  negative

# %% [markdown]
# # Cleaning

# %% [markdown]
# # Removal of URLS

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub('', text)

df['text'] = df['text'].apply(remove_urls)
df.head(20)
# Out:
#     Unnamed: 0                                               text    labels
# 0            0                 team 2019merimera alikuwa takataka  negative
# 1            1                                     sijafurahishwa  negative
# 2            2                                      kubuni dosari  negative
# 3            3                  bila kusema nilipoteza pesa zangu  negative
# 4            4                       sema kupoteza pesa na wakati  negative
# 5            5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6            6                                  akili yako imeoza  negative
# 7            7                            aki si maisha ni magumu  negative
# 8            8                           enyewe safaricom ni wezi  negative
# 9            9  mtandao duni hata line yao niliweka nyuma ya s...  negative
# 10          10  mtandao wenu wa 4g ni mbaya sana siku hizi taf...  negative
# 11          11  safaricom si muache kucheza na mkopo wa nambar...  negative
# 12          12                                         hauna haki  negative
# 13          13  nyinyi mimi nilinunua laini yenu miaka 20 iliy...  negative
# 14          14  siwezi kuona jinsi sinema hii inavyoweza kuwa ...  negative
# 15          15  ni mbaya sana ni kweli inafaa kuona kwa sababu...  negative
# 16          16  muziki mdogo sana au kitu chochote cha kuzungu...  negative
# 17          17  bado mtaishi kuwa wakora ata hii ofa labda kun...  negative
# 18          18                            nimepoteza masaa mawili  negative
# 19          19                          inaweza kutabirika kidogo  negative

# %% [markdown]
# # Removal of Special Characters

# %%
#Remove special characters
def remove_special_characters(text):
    pattern = r'[^a-zA-Z0-9\s]' # keep only alphanumeric and whitespace characters
    text = re.sub(pattern, '', text)
    return text

df['text'] = df['text'].apply(remove_special_characters)
df.head(20)
# Out:
#     Unnamed: 0                                               text    labels
# 0            0                 team 2019merimera alikuwa takataka  negative
# 1            1                                     sijafurahishwa  negative
# 2            2                                      kubuni dosari  negative
# 3            3                  bila kusema nilipoteza pesa zangu  negative
# 4            4                       sema kupoteza pesa na wakati  negative
# 5            5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6            6                                  akili yako imeoza  negative
# 7            7                            aki si maisha ni magumu  negative
# 8            8                           enyewe safaricom ni wezi  negative
# 9            9  mtandao duni hata line yao niliweka nyuma ya s...  negative
# 10          10  mtandao wenu wa 4g ni mbaya sana siku hizi taf...  negative
# 11          11  safaricom si muache kucheza na mkopo wa nambar...  negative
# 12          12                                         hauna haki  negative
# 13          13  nyinyi mimi nilinunua laini yenu miaka 20 iliy...  negative
# 14          14  siwezi kuona jinsi sinema hii inavyoweza kuwa ...  negative
# 15          15  ni mbaya sana ni kweli inafaa kuona kwa sababu...  negative
# 16          16  muziki mdogo sana au kitu chochote cha kuzungu...  negative
# 17          17  bado mtaishi kuwa wakora ata hii ofa labda kun...  negative
# 18          18                            nimepoteza masaa mawili  negative
# 19          19                          inaweza kutabirika kidogo  negative

# %% [markdown]
# # Coverting text into lower case

# %%
df['text'] = df['text'].str.lower()
df.head(20)
# Out:
#     Unnamed: 0                                               text    labels
# 0            0                 team 2019merimera alikuwa takataka  negative
# 1            1                                     sijafurahishwa  negative
# 2            2                                      kubuni dosari  negative
# 3            3                  bila kusema nilipoteza pesa zangu  negative
# 4            4                       sema kupoteza pesa na wakati  negative
# 5            5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6            6                                  akili yako imeoza  negative
# 7            7                            aki si maisha ni magumu  negative
# 8            8                           enyewe safaricom ni wezi  negative
# 9            9  mtandao duni hata line yao niliweka nyuma ya s...  negative
# 10          10  mtandao wenu wa 4g ni mbaya sana siku hizi taf...  negative
# 11          11  safaricom si muache kucheza na mkopo wa nambar...  negative
# 12          12                                         hauna haki  negative
# 13          13  nyinyi mimi nilinunua laini yenu miaka 20 iliy...  negative
# 14          14  siwezi kuona jinsi sinema hii inavyoweza kuwa ...  negative
# 15          15  ni mbaya sana ni kweli inafaa kuona kwa sababu...  negative
# 16          16  muziki mdogo sana au kitu chochote cha kuzungu...  negative
# 17          17  bado mtaishi kuwa wakora ata hii ofa labda kun...  negative
# 18          18                            nimepoteza masaa mawili  negative
# 19          19                          inaweza kutabirika kidogo  negative

# %% [markdown]
# # Tokenizing the data

# %%
df['tokens'] = df['text'].apply(nltk.word_tokenize)
df.head(10)
# Out:
#    Unnamed: 0                                               text    labels  \
# 0           0                 team 2019merimera alikuwa takataka  negative
# 1           1                                     sijafurahishwa  negative
# 2           2                                      kubuni dosari  negative
# 3           3                  bila kusema nilipoteza pesa zangu  negative
# 4           4                       sema kupoteza pesa na wakati  negative
# 5           5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6           6                                  akili yako imeoza  negative
# 7           7                            aki si maisha ni magumu  negative
# 8           8                           enyewe safaricom ni wezi  negative
# 9           9  mtandao duni hata line yao niliweka nyuma ya s...  negative
#
#                                               tokens
# 0            [team, 2019merimera, alikuwa, takataka]
# 1                                   [sijafurahishwa]
# 2                                   [kubuni, dosari]
# 3            [bila, kusema, nilipoteza, pesa, zangu]
# 4                 [sema, kupoteza, pesa, na, wakati]
# 5  [ubunifu, ni, isiyo, ya, kawaida, sana, kwani,...
# 6                              [akili, yako, imeoza]
# 7                      [aki, si, maisha, ni, magumu]
# 8                      [enyewe, safaricom, ni, wezi]
# 9  [mtandao, duni, hata, line, yao, niliweka, nyu...

# %% [markdown]
# # Removal of Stopwords

# %%
nltk.download('stopwords')
import nltk
nltk.data.path
from nltk.corpus import stopwords

def remove_stopwords(tokens):
    stopwords_list = stopwords.words('swahili')
    filtered_tokens = [token for token in tokens if token.lower() not in stopwords_list]
    return filtered_tokens

df['tokens'] = df['tokens'].apply(remove_stopwords)

df.head(10)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
#    Unnamed: 0                                               text    labels  \
# 0           0                 team 2019merimera alikuwa takataka  negative
# 1           1                                     sijafurahishwa  negative
# 2           2                                      kubuni dosari  negative
# 3           3                  bila kusema nilipoteza pesa zangu  negative
# 4           4                       sema kupoteza pesa na wakati  negative
# 5           5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6           6                                  akili yako imeoza  negative
# 7           7                            aki si maisha ni magumu  negative
# 8           8                           enyewe safaricom ni wezi  negative
# 9           9  mtandao duni hata line yao niliweka nyuma ya s...  negative
#
#                                               tokens
# 0                     [team, 2019merimera, takataka]
# 1                                   [sijafurahishwa]
# 2                                   [kubuni, dosari]
# 3                  [kusema, nilipoteza, pesa, zangu]
# 4                             [sema, kupoteza, pesa]
# 5  [ubunifu, isiyo, kawaida, kwani, kipande, siki...
# 6                              [akili, yako, imeoza]
# 7                          [aki, si, maisha, magumu]
# 8                          [enyewe, safaricom, wezi]
# 9  [mtandao, duni, line, niliweka, nyuma, simu, y...

# %% [markdown]
# # Training the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
df.head(10)
# Out:
#    Unnamed: 0                                               text    labels  \
# 0           0                 team 2019merimera alikuwa takataka  negative
# 1           1                                     sijafurahishwa  negative
# 2           2                                      kubuni dosari  negative
# 3           3                  bila kusema nilipoteza pesa zangu  negative
# 4           4                       sema kupoteza pesa na wakati  negative
# 5           5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6           6                                  akili yako imeoza  negative
# 7           7                            aki si maisha ni magumu  negative
# 8           8                           enyewe safaricom ni wezi  negative
# 9           9  mtandao duni hata line yao niliweka nyuma ya s...  negative
#
#                                               tokens
# 0                     [team, 2019merimera, takataka]
# 1                                   [sijafurahishwa]
# 2                                   [kubuni, dosari]
# 3                  [kusema, nilipoteza, pesa, zangu]
# 4                             [sema, kupoteza, pesa]
# 5  [ubunifu, isiyo, kawaida, kwani, kipande, siki...
# 6                              [akili, yako, imeoza]
# 7                          [aki, si, maisha, magumu]
# 8                          [enyewe, safaricom, wezi]
# 9  [mtandao, duni, line, niliweka, nyuma, simu, y...

# %% [markdown]
# # Spliting the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['labels'], test_size=0.2, random_state=42)
df.head(10)
# Out:
#    Unnamed: 0                                               text    labels  \
# 0           0                 team 2019merimera alikuwa takataka  negative
# 1           1                                     sijafurahishwa  negative
# 2           2                                      kubuni dosari  negative
# 3           3                  bila kusema nilipoteza pesa zangu  negative
# 4           4                       sema kupoteza pesa na wakati  negative
# 5           5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6           6                                  akili yako imeoza  negative
# 7           7                            aki si maisha ni magumu  negative
# 8           8                           enyewe safaricom ni wezi  negative
# 9           9  mtandao duni hata line yao niliweka nyuma ya s...  negative
#
#                                               tokens
# 0                     [team, 2019merimera, takataka]
# 1                                   [sijafurahishwa]
# 2                                   [kubuni, dosari]
# 3                  [kusema, nilipoteza, pesa, zangu]
# 4                             [sema, kupoteza, pesa]
# 5  [ubunifu, isiyo, kawaida, kwani, kipande, siki...
# 6                              [akili, yako, imeoza]
# 7                          [aki, si, maisha, magumu]
# 8                          [enyewe, safaricom, wezi]
# 9  [mtandao, duni, line, niliweka, nyuma, simu, y...

# %% [markdown]
# # Converting the text data into a numerical format using CountVectorizer

# %%
vectorizer = CountVectorizer(stop_words='swahili')
swahili_stop_words = ["kwamba", "ni", "ya", "kwa", "na", ...]  
vectorizer = CountVectorizer(stop_words=swahili_stop_words)
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)
df.head(10)
# Out:
#    Unnamed: 0                                               text    labels  \
# 0           0                 team 2019merimera alikuwa takataka  negative
# 1           1                                     sijafurahishwa  negative
# 2           2                                      kubuni dosari  negative
# 3           3                  bila kusema nilipoteza pesa zangu  negative
# 4           4                       sema kupoteza pesa na wakati  negative
# 5           5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6           6                                  akili yako imeoza  negative
# 7           7                            aki si maisha ni magumu  negative
# 8           8                           enyewe safaricom ni wezi  negative
# 9           9  mtandao duni hata line yao niliweka nyuma ya s...  negative
#
#                                               tokens
# 0                     [team, 2019merimera, takataka]
# 1                                   [sijafurahishwa]
# 2                                   [kubuni, dosari]
# 3                  [kusema, nilipoteza, pesa, zangu]
# 4                             [sema, kupoteza, pesa]
# 5  [ubunifu, isiyo, kawaida, kwani, kipande, siki...
# 6                              [akili, yako, imeoza]
# 7                          [aki, si, maisha, magumu]
# 8                          [enyewe, safaricom, wezi]
# 9  [mtandao, duni, line, niliweka, nyuma, simu, y...

# %% [markdown]
# # Train a Naive Bayes classifier on the training data

# %%
clf = MultinomialNB()
clf.fit(X_train_vec, y_train)
df.head(10)
# Out:
#    Unnamed: 0                                               text    labels  \
# 0           0                 team 2019merimera alikuwa takataka  negative
# 1           1                                     sijafurahishwa  negative
# 2           2                                      kubuni dosari  negative
# 3           3                  bila kusema nilipoteza pesa zangu  negative
# 4           4                       sema kupoteza pesa na wakati  negative
# 5           5  ubunifu ni isiyo ya kawaida sana kwani kipande...  negative
# 6           6                                  akili yako imeoza  negative
# 7           7                            aki si maisha ni magumu  negative
# 8           8                           enyewe safaricom ni wezi  negative
# 9           9  mtandao duni hata line yao niliweka nyuma ya s...  negative
#
#                                               tokens
# 0                     [team, 2019merimera, takataka]
# 1                                   [sijafurahishwa]
# 2                                   [kubuni, dosari]
# 3                  [kusema, nilipoteza, pesa, zangu]
# 4                             [sema, kupoteza, pesa]
# 5  [ubunifu, isiyo, kawaida, kwani, kipande, siki...
# 6                              [akili, yako, imeoza]
# 7                          [aki, si, maisha, magumu]
# 8                          [enyewe, safaricom, wezi]
# 9  [mtandao, duni, line, niliweka, nyuma, simu, y...

# %% [markdown]
# # Evaluating the classifier on the testing data

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Predict the sentiment labels for the testing data
y_pred = clf.predict(X_test_vec)

# Calculate the accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Calculate the precision of the classifier
precision = precision_score(y_test, y_pred, average='macro')
print("Precision:", precision)

# Calculate the recall of the classifier
recall = recall_score(y_test, y_pred, average='macro')
print("Recall:", recall)

# Calculate the F1-score of the classifier
f1_score = f1_score(y_test, y_pred, average='macro')
print("F1-score:", f1_score)
# Out:
# Accuracy: 0.7770700636942676
# Precision: 0.7769445130110558
# Recall: 0.7769085382487042
# F1-score: 0.7769252628587666

# %% [markdown]
# # Training the Support Vector Machine model with a higher max_iter parameter

# %%
from sklearn.svm import SVC

# Create an SVM classifier object with a higher max_iter parameter
svm_clf = SVC(kernel='linear', C=1, max_iter=30000)

# Train the SVM classifier on the training data
svm_clf.fit(X_train_vec, y_train)

# Evaluate the SVM classifier on the testing data
svm_acc = svm_clf.score(X_test_vec, y_test)

print("Accuracy of SVM classifier: {:.2f}%".format(svm_acc * 100))
# Out:
# Accuracy of SVM classifier: 81.15%

# %% [markdown]
# # Evaluating the Support Vector Machine

# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# Load the iris dataset
iris = load_iris()

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=42)

# Create an SVM model and fit it to the training data
svm = SVC(kernel='linear', C=1)
svm.fit(X_train, y_train)

# Make predictions on the testing data
y_pred = svm.predict(X_test)

# Print the confusion matrix and classification report
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # Loading the trained Support Vector Machine model

# %%
# Load the training data from a CSV file
train_data = pd.read_csv("swahili.csv")

# Define the vectorizer
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the training data
vectorizer.fit(train_data['text'])

# Transform the training data
train_vectors = vectorizer.transform(train_data['text'])

# Define the LinearSVC model
svm_model = LinearSVC()

# Train the model on the training data
svm_model.fit(train_vectors, train_data['labels'])

# Process the new tweet
tweet = "nafasi ya pekee ya filamu hiyo ilikuwa ni yona hill ambaye ataonekana kutofahamika kwa mashabiki wa superbad ya hivi karibuni kutokana na uzito uliopotea mwakani"
new_tweet_vector = vectorizer.transform([tweet])

# Predict the sentiment of the new tweet
new_tweet_sentiment = svm_model.predict(new_tweet_vector)

# Print the sentiment of the new tweet
print("The label of this Swahili text is: " + new_tweet_sentiment[0])

train_data.head()
# Out:
# The label of this Swahili text is: positive
#    Unnamed: 0                                text    labels
# 0           0  team 2019merimera alikuwa takataka  negative
# 1           1                      sijafurahishwa  negative
# 2           2                       kubuni dosari  negative
# 3           3   bila kusema nilipoteza pesa zangu  negative
# 4           4        sema kupoteza pesa na wakati  negative

# %% [markdown]
# # Deploying the Model

# %%
# !pip install gradio
import gradio as gr

def predict_sentiment(tweet):
    # Process the new tweet
    new_tweet_vector = vectorizer.transform([tweet])

    # Predict the sentiment of the new tweet
    new_tweet_sentiment = svm_model.predict(new_tweet_vector)

    return new_tweet_sentiment[0]

tweet_input = gr.inputs.Textbox(lines=3, label="Enter your tweet")
prediction = gr.outputs.Label(label="The Sentiment of this tweet is : ")

gradio_interface = gr.Interface(fn=predict_sentiment, inputs=tweet_input, outputs=prediction, title='Swahili Sentiment Analyzer', 
             description='Enter a text in Swahili to determine its sentiment')
gradio_interface.launch(share=True)
# Out:
# Collecting gradio
#   Downloading gradio-3.24.1-py3-none-any.whl (15.7 MB)
#      -------------------------------------- 15.7/15.7 MB 191.5 kB/s eta 0:00:00
# Requirement already satisfied: pyyaml in c:\users\hp\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: markupsafe in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.0.1)
# Collecting websockets>=10.0
#   Downloading websockets-11.0.1-cp39-cp39-win_amd64.whl (124 kB)
#      ------------------------------------- 124.5/124.5 kB 92.6 kB/s eta 0:00:00
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      -------------------------------------- 45.7/45.7 kB 125.8 kB/s eta 0:00:00
# Collecting gradio-client>=0.0.5
#   Downloading gradio_client-0.0.8-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (from gradio) (1.4.4)
# Collecting uvicorn
#   Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
#      -------------------------------------- 57.8/57.8 kB 152.5 kB/s eta 0:00:00
# Collecting httpx
#   Using cached httpx-0.23.3-py3-none-any.whl (71 kB)
# Collecting pydantic
#   Downloading pydantic-1.10.7-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 215.4 kB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from gradio) (9.2.0)
# Collecting fastapi
#   Downloading fastapi-0.95.0-py3-none-any.whl (57 kB)
#      -------------------------------------- 57.1/57.1 kB 755.2 kB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.11.3)
# Collecting orjson
#   Downloading orjson-3.8.9-cp39-none-win_amd64.whl (202 kB)
#      ------------------------------------ 202.1/202.1 kB 157.5 kB/s eta 0:00:00
# Collecting altair>=4.2.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ------------------------------------- 813.6/813.6 kB 78.0 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from gradio) (1.21.5)
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\hp\anaconda3\lib\site-packages (from gradio) (4.3.0)
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting huggingface-hub>=0.13.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ------------------------------------- 200.1/200.1 kB 69.8 kB/s eta 0:00:00
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      --------------------------------------- 50.5/50.5 kB 78.1 kB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-win_amd64.whl (323 kB)
#      ------------------------------------- 323.6/323.6 kB 70.6 kB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from gradio) (3.5.2)
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting markdown-it-py[linkify]>=2.0.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      --------------------------------------- 84.5/84.5 kB 58.6 kB/s eta 0:00:00
# Requirement already satisfied: toolz in c:\users\hp\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.11.2)
# Requirement already satisfied: entrypoints in c:\users\hp\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from altair>=4.2.0->gradio) (4.16.0)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\lib\site-packages (from gradio-client>=0.0.5->gradio) (2022.7.1)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from gradio-client>=0.0.5->gradio) (21.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.13.0->gradio) (4.64.1)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.13.0->gradio) (3.6.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->gradio) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->gradio) (21.4.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-win_amd64.whl (56 kB)
#      --------------------------------------- 56.8/56.8 kB 87.5 kB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-win_amd64.whl (34 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp->gradio) (2.0.4)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting starlette<0.27.0,>=0.26.1
#   Downloading starlette-0.26.1-py3-none-any.whl (66 kB)
#      -------------------------------------- 66.9/66.9 kB 103.6 kB/s eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from httpx->gradio) (1.2.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from httpx->gradio) (2022.9.14)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Using cached httpcore-0.16.3-py3-none-any.whl (69 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->gradio) (1.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->gradio) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->gradio) (1.26.11)
# Collecting h11>=0.8
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: click>=7.0 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn->gradio) (8.0.4)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click>=7.0->uvicorn->gradio) (0.4.5)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.18.0)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py): started
#   Building wheel for ffmpy (setup.py): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4693 sha256=691a8b2c829fad5ae9295e09caa434a632e872ed06406a135784e1b76dbbed7c
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\91\e2\96\f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
# Successfully built ffmpy
# Installing collected packages: rfc3986, pydub, ffmpy, websockets, uc-micro-py, semantic-version, python-multipart, pydantic, orjson, multidict, mdurl, h11, frozenlist, async-timeout, aiofiles, yarl, uvicorn, starlette, markdown-it-py, linkify-it-py, huggingface-hub, httpcore, aiosignal, mdit-py-plugins, httpx, gradio-client, fastapi, altair, aiohttp, gradio
# Successfully installed aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 altair-4.2.2 async-timeout-4.0.2 fastapi-0.95.0 ffmpy-0.3.0 frozenlist-1.3.3 gradio-3.24.1 gradio-client-0.0.8 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 huggingface-hub-0.13.4 linkify-it-py-2.0.0 markdown-it-py-2.2.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 multidict-6.0.4 orjson-3.8.9 pydantic-1.10.7 pydub-0.25.1 python-multipart-0.0.6 rfc3986-1.5.0 semantic-version-2.10.0 starlette-0.26.1 uc-micro-py-1.0.1 uvicorn-0.21.1 websockets-11.0.1 yarl-1.8.2
# C:\Users\HP\anaconda3\lib\site-packages\gradio\inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\HP\anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# C:\Users\HP\anaconda3\lib\site-packages\gradio\outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\gradio\deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://be686f8f1359e99f7b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://be686f8f1359e99f7b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
